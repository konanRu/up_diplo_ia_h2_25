# %%
from statsmodels.stats.descriptivestats import describe
import statsmodels.api as sm
import pandas as pd

# %%
data_electric = pd.read_csv("cars-electric.csv")
data_cars = pd.read_csv("cars.csv")

# %%
data_cars.describe()
# Out:
#                Year  Engine Size (L)   Price (USD)
# count  10000.000000     10000.000000  10000.000000
# mean    2014.969900         2.992240  47397.584981
# std        3.174303         1.150697  18643.431581
# min     2010.000000         1.000000  15010.250000
# 25%     2012.000000         2.000000  31214.385000
# 50%     2015.000000         3.000000  47272.105000
# 75%     2018.000000         4.000000  63325.882500
# max     2020.000000         5.000000  79998.870000

# %%
describe(data_cars)
# Out:
#                            Year  Engine Size (L)    Price (USD)
# nobs               1.000000e+04     1.000000e+04   1.000000e+04
# missing            0.000000e+00     0.000000e+00   0.000000e+00
# mean               2.014970e+03     2.992240e+00   4.739758e+04
# std_err            3.174303e-02     1.150697e-02   1.864343e+02
# upper_ci           2.015032e+03     3.014793e+00   4.776299e+04
# lower_ci           2.014908e+03     2.969687e+00   4.703218e+04
# std                3.174303e+00     1.150697e+00   1.864343e+04
# iqr                6.000000e+00     2.000000e+00   3.211150e+04
# iqr_normal         4.447807e+00     1.482602e+00   2.380429e+04
# mad                2.735203e+00     9.957104e-01   1.608875e+04
# mad_normal         3.428069e+00     1.247938e+00   2.016425e+04
# coef_var           1.575360e-03     3.845605e-01   3.933414e-01
# range              1.000000e+01     4.000000e+00   6.498862e+04
# max                2.020000e+03     5.000000e+00   7.999887e+04
# ...

# %%
data_cars["Engine Size (L)"].plot.hist(bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %%
data_cars['Price (USD)'].plot.box()
# Out:
# <Axes: >

# %%
ds = data_cars.describe()
ds.reset_index(inplace=True)
print(ds)
data_cars.pivot_table(columns=)
data_cars[['Price (USD)','Engine Size (L)']].plot(y='Price (USD)',x='Engine Size (L)', kind='scatter')
# Out:
#    index          Year  Engine Size (L)   Price (USD)
# 0  count  10000.000000     10000.000000  10000.000000
# 1   mean   2014.969900         2.992240  47397.584981
# 2    std      3.174303         1.150697  18643.431581
# 3    min   2010.000000         1.000000  15010.250000
# 4    25%   2012.000000         2.000000  31214.385000
# 5    50%   2015.000000         3.000000  47272.105000
# 6    75%   2018.000000         4.000000  63325.882500
# 7    max   2020.000000         5.000000  79998.870000
# <Axes: xlabel='Engine Size (L)', ylabel='Price (USD)'>
